# %% [markdown]
# <a href="https://colab.research.google.com/github/prathmeshk71/Hokage/blob/main/Numpy_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.version
# Out:
# <module 'numpy.version' from '/usr/local/lib/python3.12/dist-packages/numpy/version.py'>

# %%
one_D = np.array([1, 2, 3, 4])
print("it is one-Dimensional array:",one_D)
print("its type:",type(one_D))
# Out:
# it is one-Dimensional array: [1 2 3 4]
# its type: <class 'numpy.ndarray'>

# %%
twoD_arr = np.array([[1, 2, 3], [4, 5, 6]])
print(twoD_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
threeD_arr = np.array(
    [
        [
            [1, 2, 3], [4, 5, 6]
            ],
        [
            [1, 2, 3], [4, 5, 6]
            ]
        ]
    )
print(threeD_arr)
np.size(threeD_arr)
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]
# 12

# %%
records = [
    ("aman", 18, 90),
    ("prakash", 19, 60),
    ("abhijit", 20, 89),
]
print("this Record function:", records)
data = np.array(records, dtype = [("name", "U15"), ("age", np.int32), ("marks", np.float32), ])
data
# Out:
# this Record function: [('aman', 18, 90), ('prakash', 19, 60), ('abhijit', 20, 89)]
# array([('aman', 18, 90.), ('prakash', 19, 60.), ('abhijit', 20, 89.)],
#       dtype=[('name', '<U15'), ('age', '<i4'), ('marks', '<f4')])

# %%
print(data[2])
# Out:
# ('abhijit', 20, 89.0)

# %%
print(data["marks"])
# Out:
# [90. 60. 89.]
